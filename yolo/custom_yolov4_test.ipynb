# %% [markdown]
# **change directory to yolo folder**

# %%
# %cd /content/drive/MyDrive/HNN/yolo
# %ls
# Out:
# /content/drive/MyDrive/HNN/yolo
# backup/                   detect_mnist.py    README.md
# checkpoints/              evaluate_mAP.py    requirements.txt
# Collect_training_data.py  IMAGES/            tools/
# custom_dataset/           LICENSE            train.py
# custom_yolov4_test.ipynb  log/               Untitled0.ipynb
# deep_sort/                mAP/               yolov3/
# dete/                     mnist/             YOLOv3_colab_training.ipynb
# detection/                model_data/        yolov4_custom_dataset.ipynb
# detection_custom.py       object_tracker.py
# detection_demo.py         __pycache__/

# %% [markdown]
# **Install all required libraries for this project**

# %%
# !pip install -r ./requirements.txt

# %% [markdown]
# **Test if TensorFlow works with gpu for you, in output should see similar results:** <br>
#
# 2.3.0<br>
# '/device:GPU:0'

# %%
import tensorflow as tf
print(tf.__version__)
tf.test.gpu_device_name()
# Out:
# 2.3.1
# '/device:GPU:0'

# %% [markdown]
# **Test by testing detection on original model:**

# %%
# %cd /content/drive/MyDrive/HNN/yolo
# %ls
# Out:
# /content/drive/MyDrive/HNN/yolo
# backup/                   detect_mnist.py    README.md
# checkpoints/              evaluate_mAP.py    requirements.txt
# Collect_training_data.py  IMAGES/            tools/
# custom_dataset/           LICENSE            train.py
# custom_yolov4_test.ipynb  log/               Untitled0.ipynb
# deep_sort/                mAP/               yolov3/
# dete/                     mnist/             YOLOv3_colab_training.ipynb
# detection/                model_data/        yolov4_custom_dataset.ipynb
# detection_custom.py       object_tracker.py
# detection_demo.py         __pycache__/

# %%
import cv2
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
import tensorflow as tf
from yolov3.yolov4 import Create_Yolo
from yolov3.utils import load_yolo_weights, detect_image
from yolov3.configs import *

if YOLO_TYPE == "yolov4":
    Darknet_weights = YOLO_V4_TINY_WEIGHTS if TRAIN_YOLO_TINY else YOLO_V4_WEIGHTS
if YOLO_TYPE == "yolov3":
    Darknet_weights = YOLO_V3_TINY_WEIGHTS if TRAIN_YOLO_TINY else YOLO_V3_WEIGHTS

yolo = Create_Yolo(input_size=YOLO_INPUT_SIZE)
load_yolo_weights(yolo, Darknet_weights) # use Darknet weights

# %% [markdown]
# **Test by testing detection on original model:**

# %%
image_path   = "./IMAGES/city.jpg"

image = detect_image(yolo, image_path, '', input_size=YOLO_INPUT_SIZE, show=False, rectangle_colors=(255,0,0))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(30,15))
plt.imshow(image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Test the detection with image**

# %%
# !python detection_custom.py
# Out:
# 2021-12-09 00:15:36.077776: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ./model_data/pet_names.txt
#  ******
# 2021-12-09 00:15:37.486672: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-12-09 00:15:37.491029: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-09 00:15:37.491479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-12-09 00:15:37.491536: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
