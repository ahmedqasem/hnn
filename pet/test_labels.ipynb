# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import cv2

# %%
# load annotation df
df = pd.read_csv('/content/drive/MyDrive/HNN/data/pet/train_annotate.txt', header=None)
df.tail()

# %%
img = cv2.imread('/content/drive/MyDrive/HNN/data/pet/train/HN-HGJ-080-45.png')

# %%
plt.imshow(img, cmap='gray')

# %%
labels = [x for x in df.iloc[270].loc[1:4]]
labels

# %%
rect = cv2.rectangle(img, (labels[0], labels[1]), (labels[2], labels[3]), (0,255,0),3)

# %%
plt.imshow(rect, cmap='gray')
